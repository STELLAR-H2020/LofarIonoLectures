# %% [markdown]
# ### Geomagnetic activity
# #### In this notebook, we will check the geomagnetic activity based on ASY/SYM and auroral indices at the time of LOFAR observation L80898 (starting on 19.12.2012 at 21:49), using pandas library

# %% [markdown]
# You should first download the relevant [geomagnetic indices](https://wdc.kugi.kyoto-u.ac.jp/aeasy/index.html) in the IAGA2002 format (both AE and ASY/SYM), covering 2 full days 19-20.12.2012

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Let's start with the ASY/SYM indices and load the file

# %%
magind = (pd.read_csv('ASY.txt',header=14,delimiter='\s+'))

# %% [markdown]
# Check the data type

# %%
type(magind)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# We can check the variables that exist in the DataFrame

# %%
magind.keys()
# Out:
# Index(['DATE', 'TIME', 'DOY', 'ASY-D', 'ASY-H', 'SYM-D', 'SYM-H', '|'], dtype='object')

# %% [markdown]
# To see a preview of the DataFrame content we can use:

# %%
magind.head()
# Out:
#          DATE          TIME  DOY  ASY-D  ASY-H  SYM-D  SYM-H   |
# 0  2012-12-19  00:00:00.000  354    7.0   12.0   -2.0   -9.0 NaN
# 1  2012-12-19  00:01:00.000  354    7.0   13.0   -1.0   -9.0 NaN
# 2  2012-12-19  00:02:00.000  354    5.0   13.0   -2.0   -8.0 NaN
# 3  2012-12-19  00:03:00.000  354    5.0   13.0   -2.0   -9.0 NaN
# 4  2012-12-19  00:04:00.000  354    5.0   14.0   -2.0   -9.0 NaN

# %% [markdown]
# We can plot the chosen variables with

# %%
magind.plot(x='TIME',y=['ASY-H','ASY-D'],rot=45)
plt.xlabel('UTC [h]')
plt.ylabel('ASY [nT]')
plt.ylim(0,70)
plt.show()
plt.close()

# %%
magind.plot(x='TIME',y=['SYM-H','SYM-D'],rot=45)
plt.xlabel('UTC [h]')
plt.ylabel('SYM [nT]')
plt.ylim(-40,20)
plt.show()
plt.close()

# %% [markdown]
# Above plots are for the whole 2 days to check the overall conditions. Let's zoom it on the time of our observation:

# %%
magind.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y=['ASY-H','ASY-D'],rot=45)
plt.xlabel('UTC [h]')
plt.ylabel('ASY-D [nT]')
plt.ylim(0,50)
plt.show()
plt.close()

# %% [markdown]
# We will now investigate the auroral indices:

# %%
magindae = (pd.read_csv('AE.txt',header=14,delimiter='\s+'))
magindae.head()
# Out:
#          DATE          TIME  DOY    AE    AU    AL    AO   |
# 0  2012-12-19  00:00:00.000  354  92.0  14.0 -78.0 -32.0 NaN
# 1  2012-12-19  00:01:00.000  354  81.0  15.0 -66.0 -26.0 NaN
# 2  2012-12-19  00:02:00.000  354  63.0  13.0 -50.0 -19.0 NaN
# 3  2012-12-19  00:03:00.000  354  68.0  25.0 -43.0  -9.0 NaN
# 4  2012-12-19  00:04:00.000  354  70.0  15.0 -55.0 -20.0 NaN

# %% [markdown]
# #### Exercise
#
# Make two separate plots of AE, AO and AL, AU indices for the observation's time span

# %%
magindae.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y=['AU','AL'],rot=45)
plt.xlabel('UTC [h]')
plt.ylabel('AE,AO [nT]')
#plt.ylim(-40,20)
plt.show()
plt.close()

# %% [markdown]
# #### Exercise
#
# Plot AE index and ASY-H index in the same figure, for the observation's time span
#
# Plot the same for AE and ASY-D index

# %%
axs=magindae.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y='AE',rot=45)
axs2=axs.twinx()
magind.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y='ASY-H',rot=45,ax=axs2,c='red')
axs.set_xlabel('UTC [h]')
axs.set_ylabel('AE [nT]')
axs2.set_ylabel('ASY-H [nT]')
plt.show()
plt.close()

axs=magindae.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y='AE',rot=45)
axs2=axs.twinx()
magind.iloc[(21*60+50):(30*60+50)].plot(x='TIME',y='ASY-D',rot=45,ax=axs2,c='red')
axs.set_xlabel('UTC [h]')
axs.set_ylabel('AE [nT]')
axs2.set_ylabel('ASY-D [nT]')
plt.show()
plt.close()
